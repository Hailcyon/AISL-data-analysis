# %%
#IMPORTS

import pandas as pd

# %%
#ADD DATAFRAMES

janFeb_inGallery_text = pd.read_csv("c:/Users/Hailey Sherman/ClimateOfHopeData/Data_2025/TEXT_jan-feb_2024_pre_in-gallery_post_data.csv")
febJune_inGallery_text = pd.read_csv("c:/Users/Hailey Sherman/ClimateOfHopeData/Data_2025/TEXT_Feb-June_25_2024_pre_in-gallery_post_data.csv")
SPUR_predictors_and_outcomes = pd.read_excel("c:/Users/Hailey Sherman/ClimateOfHopeData/Data_2025/Cleaned_survey_predictors_and_outcomes_plus.xlsx")

# %%
#set displays to show all data

pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", None)

# %%
display(janFeb_inGallery_text)

# %%
display(febJune_inGallery_text)
# Out:
#                                              StartDate  \
# 0                                           Start Date
# 1    {"ImportId":"startDate","timeZone":"America/De...
# 2                                  2024-02-23 13:48:47
# 3                                  2024-02-23 14:01:30
# 4                                  2024-02-23 13:49:43
# 5                                  2024-02-23 14:02:31
# 6                                  2024-02-23 13:57:22
# 7                                  2024-02-23 13:50:21
# 8                                  2024-02-23 13:26:48
# 9                                  2024-02-24 11:09:09
# 10                                 2024-02-23 15:12:38
# 11                                 2024-02-24 11:13:27
# 12                                 2024-02-23 15:37:25
# 13                                 2024-02-23 15:37:35
# 14                                 2024-02-24 11:23:51
# 15                                 2024-02-23 13:22:58
# ...

# %%
display(SPUR_predictors_and_outcomes)
# Out:
#                       ida   age             gender       sassy  \
# 0              20010501BJ  23.0                NaN         NaN
# 1              24011901AW   5.0  Prefer not to say         NaN
# 2              24011901AY  33.0             Female         NaN
# 3              24011901MR  18.0             Female         NaN
# 4              24011902CB  72.0              Other         NaN
# 5              24012401BF  23.0               Male     Alarmed
# 6              24012401MG  23.0               Male    Cautious
# 7              24012401PM  22.0               Male     Alarmed
# 8              24012601LS  63.0             Female   Concerned
# 9              24012601RS  59.0               Male    Doubtful
# 10             24012602CM  30.0             Female     Alarmed
# 11             24012602MM  30.0               Male     Alarmed
# 12             24012603AJ  19.0               Male   Concerned
# 13             24012603MP  18.0             Female     Alarmed
# ...

# %%
merged_df = pd.merge(janFeb_inGallery_text, febJune_inGallery_text, on="common_column_name")
