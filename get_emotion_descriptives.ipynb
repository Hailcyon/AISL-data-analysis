# %%
#IMPORTS

import pandas as pd

# %%
clean_analysis_df = pd.read_excel('c:/Users/Hailey Sherman/ClimateOfHopeData/Data_2025/COMBINED_TEXT_jan-june_pre_in-gallery_post_with_descriptions.xlsx')

# %%
display(clean_analysis_df)
# Out:
#                                             start_date  \
# 0                                           Start Date
# 1    {"ImportId":"startDate","timeZone":"America/De...
# 2                                  2024-01-24 16:52:41
# 3                                  2024-01-24 16:32:42
# 4                                  2024-01-24 16:36:52
# ..                                                 ...
# 184                                2024-04-06 14:36:07
# 185                                2024-04-06 14:35:16
# 186                                2024-04-06 14:34:46
# 187                                2024-04-06 13:48:14
# 188                                2024-04-06 15:11:50
#
#                                               end_date                 status  \
# 0                                             End Date          Response Type
# 1    {"ImportId":"endDate","timeZone":"America/Denv...  {"ImportId":"status"}
# ...

# %%
"""
Cell generated by Data Wrangler.
---Removes metadata, and renames emotion columns---
"""
def clean_data(clean_analysis_df):
    # Filter rows based on column: index
    clean_analysis_df = clean_analysis_df[(clean_analysis_df.index != 0) & (clean_analysis_df.index != 1)]
    # Rename column 'emotion_aspen_1' to 'aspen_indifferent'
    clean_analysis_df = clean_analysis_df.rename(columns={'emotion_aspen_1': 'aspen_indifferent'})
    # Rename column 'emotion_aspen_2' to 'aspen_sad'
    clean_analysis_df = clean_analysis_df.rename(columns={'emotion_aspen_2': 'aspen_sad'})
    # Rename column 'emotion_aspen_3' to 'aspen_hopeless'
    clean_analysis_df = clean_analysis_df.rename(columns={'emotion_aspen_3': 'aspen_hopeless'})
    # Rename column 'emotion_aspen_4' to 'aspen_interested'
    clean_analysis_df = clean_analysis_df.rename(columns={'emotion_aspen_4': 'aspen_interested'})
    # Rename column 'emotion_aspen_5' to 'aspen_afraid_scared'
    clean_analysis_df = clean_analysis_df.rename(columns={'emotion_aspen_5': 'aspen_afraid_scared'})
    # Rename column 'emotion_aspen_6' to 'aspen_optimistic_hopeful'
    clean_analysis_df = clean_analysis_df.rename(columns={'emotion_aspen_6': 'aspen_optimistic_hopeful'})
    # Rename column 'emotion_aspen_7' to 'aspen_anxious'
    clean_analysis_df = clean_analysis_df.rename(columns={'emotion_aspen_7': 'aspen_anxious'})
    # Rename column 'emotion_aspen_8' to 'aspen_inspired'
    clean_analysis_df = clean_analysis_df.rename(columns={'emotion_aspen_8': 'aspen_inspired'})
    # Rename column 'emotion_aspen_9' to 'aspen_angry_frustrated'
    clean_analysis_df = clean_analysis_df.rename(columns={'emotion_aspen_9': 'aspen_angry_frustrated'})
    # Rename column 'emotion_aspen_10' to 'aspen_happy'
    clean_analysis_df = clean_analysis_df.rename(columns={'emotion_aspen_10': 'aspen_happy'})
    # Rename column 'emotion_aspen_11' to 'aspen_guilty'
    clean_analysis_df = clean_analysis_df.rename(columns={'emotion_aspen_11': 'aspen_guilty'})
    # Rename column 'emotion_aspen_12' to 'aspen_numb'
    clean_analysis_df = clean_analysis_df.rename(columns={'emotion_aspen_12': 'aspen_numb'})
    # Rename column 'emotion_aspen_13' to 'aspen_stressed'
    clean_analysis_df = clean_analysis_df.rename(columns={'emotion_aspen_13': 'aspen_stressed'})
    # Rename column 'emotion_health_impacts_1' to 'here_now_impacts_indifferent'
    clean_analysis_df = clean_analysis_df.rename(columns={'emotion_health_impacts_1': 'here_now_impacts_indifferent'})
    # Rename column 'emotion_health_impacts_2' to 'here_now_impacts_sad'
    clean_analysis_df = clean_analysis_df.rename(columns={'emotion_health_impacts_2': 'here_now_impacts_sad'})
    # Rename column 'emotion_health_impacts_3' to 'here_now_impacts_hopeless'
    clean_analysis_df = clean_analysis_df.rename(columns={'emotion_health_impacts_3': 'here_now_impacts_hopeless'})
    # Rename column 'emotion_health_impacts_4' to 'here_now_impacts_interested'
    clean_analysis_df = clean_analysis_df.rename(columns={'emotion_health_impacts_4': 'here_now_impacts_interested'})
    # Rename column 'emotion_health_impacts_5' to 'here_now_impacts_afraid_scared'
    clean_analysis_df = clean_analysis_df.rename(columns={'emotion_health_impacts_5': 'here_now_impacts_afraid_scared'})
    # Rename column 'emotion_health_impacts_6' to 'here_now_impacts_optimistic_hopeful'
    clean_analysis_df = clean_analysis_df.rename(columns={'emotion_health_impacts_6': 'here_now_impacts_optimistic_hopeful'})
    # Rename column 'emotion_health_impacts_7' to 'here_now_impacts_anxious'
    clean_analysis_df = clean_analysis_df.rename(columns={'emotion_health_impacts_7': 'here_now_impacts_anxious'})
    # Rename column 'emotion_health_impacts_8' to 'here_now_impacts_inspired'
    clean_analysis_df = clean_analysis_df.rename(columns={'emotion_health_impacts_8': 'here_now_impacts_inspired'})
    # Rename column 'emotion_health_impacts_9' to 'here_now_impacts_angry_frustrated'
    clean_analysis_df = clean_analysis_df.rename(columns={'emotion_health_impacts_9': 'here_now_impacts_angry_frustrated'})
    # Rename column 'emotion_health_impacts_10' to 'here_now_impacts_happy'
    clean_analysis_df = clean_analysis_df.rename(columns={'emotion_health_impacts_10': 'here_now_impacts_happy'})
    # Rename column 'emotion_health_impacts_11' to 'here_now_impacts_guilty'
    clean_analysis_df = clean_analysis_df.rename(columns={'emotion_health_impacts_11': 'here_now_impacts_guilty'})
    # Rename column 'emotion_health_impacts_12' to 'here_now_impacts_numb'
    clean_analysis_df = clean_analysis_df.rename(columns={'emotion_health_impacts_12': 'here_now_impacts_numb'})
    # Rename column 'emotion_health_impacts_13' to 'here_now_impacts_stressed'
    clean_analysis_df = clean_analysis_df.rename(columns={'emotion_health_impacts_13': 'here_now_impacts_stressed'})
    # Rename column 'relatable_health' to 'relatable_here_now'
    clean_analysis_df = clean_analysis_df.rename(columns={'relatable_health': 'relatable_here_now'})
    # Rename column 'emotions_climate_sol_1' to 'build_momentum_indifferent'
    clean_analysis_df = clean_analysis_df.rename(columns={'emotions_climate_sol_1': 'build_momentum_indifferent'})
    # Rename column 'emotions_climate_sol_2' to 'build_momentum_sad'
    clean_analysis_df = clean_analysis_df.rename(columns={'emotions_climate_sol_2': 'build_momentum_sad'})
    # Rename column 'emotions_climate_sol_3' to 'build_momentum_hopeless'
    clean_analysis_df = clean_analysis_df.rename(columns={'emotions_climate_sol_3': 'build_momentum_hopeless'})
    # Rename column 'emotions_climate_sol_4' to 'build_momentum_interested'
    clean_analysis_df = clean_analysis_df.rename(columns={'emotions_climate_sol_4': 'build_momentum_interested'})
    # Rename column 'emotions_climate_sol_5' to 'build_momentum_afraid_scared'
    clean_analysis_df = clean_analysis_df.rename(columns={'emotions_climate_sol_5': 'build_momentum_afraid_scared'})
    # Rename column 'emotions_climate_sol_6' to 'build_momentum_optimistic_hopeful'
    clean_analysis_df = clean_analysis_df.rename(columns={'emotions_climate_sol_6': 'build_momentum_optimistic_hopeful'})
    # Rename column 'emotions_climate_sol_7' to 'build_momentum_anxious'
    clean_analysis_df = clean_analysis_df.rename(columns={'emotions_climate_sol_7': 'build_momentum_anxious'})
    # Rename column 'emotions_climate_sol_8' to 'build_momentum_inspired'
    clean_analysis_df = clean_analysis_df.rename(columns={'emotions_climate_sol_8': 'build_momentum_inspired'})
    # Rename column 'emotions_climate_sol_9' to 'build_momentum_angry_frustrated'
    clean_analysis_df = clean_analysis_df.rename(columns={'emotions_climate_sol_9': 'build_momentum_angry_frustrated'})
    # Rename column 'emotions_climate_sol_10' to 'build_momentum_happy'
    clean_analysis_df = clean_analysis_df.rename(columns={'emotions_climate_sol_10': 'build_momentum_happy'})
    # Rename column 'emotions_climate_sol_11' to 'build_momentum_guilty'
    clean_analysis_df = clean_analysis_df.rename(columns={'emotions_climate_sol_11': 'build_momentum_guilty'})
    # Rename column 'emotions_climate_sol_12' to 'build_momentum_numb'
    clean_analysis_df = clean_analysis_df.rename(columns={'emotions_climate_sol_12': 'build_momentum_numb'})
    # Rename column 'emotions_climate_sol_13' to 'build_momentum_stressed'
    clean_analysis_df = clean_analysis_df.rename(columns={'emotions_climate_sol_13': 'build_momentum_stressed'})
    # Rename column 'emotions_connecting_1' to 'connecting_indifferent'
    clean_analysis_df = clean_analysis_df.rename(columns={'emotions_connecting_1': 'connecting_indifferent'})
    # Rename column 'emotions_connecting_2' to 'connecting_sad'
    clean_analysis_df = clean_analysis_df.rename(columns={'emotions_connecting_2': 'connecting_sad'})
    # Rename column 'emotions_connecting_3' to 'connecting_hopeless'
    clean_analysis_df = clean_analysis_df.rename(columns={'emotions_connecting_3': 'connecting_hopeless'})
    # Rename column 'emotions_connecting_4' to 'connecting_interested'
    clean_analysis_df = clean_analysis_df.rename(columns={'emotions_connecting_4': 'connecting_interested'})
    # Rename column 'emotions_connecting_5' to 'connecting_afraid_scared'
    clean_analysis_df = clean_analysis_df.rename(columns={'emotions_connecting_5': 'connecting_afraid_scared'})
    # Rename column 'emotions_connecting_6' to 'connecting_optimistic_hopeful'
    clean_analysis_df = clean_analysis_df.rename(columns={'emotions_connecting_6': 'connecting_optimistic_hopeful'})
    # Rename column 'emotions_connecting_7' to 'connecting_anxious'
    clean_analysis_df = clean_analysis_df.rename(columns={'emotions_connecting_7': 'connecting_anxious'})
    # Rename column 'emotions_connecting_8' to 'connecting_inspired'
    clean_analysis_df = clean_analysis_df.rename(columns={'emotions_connecting_8': 'connecting_inspired'})
    # Rename column 'emotions_connecting_9' to 'connecting_angry_frustrated'
    clean_analysis_df = clean_analysis_df.rename(columns={'emotions_connecting_9': 'connecting_angry_frustrated'})
    # Rename column 'emotions_connecting_10' to 'connecting_happy'
    clean_analysis_df = clean_analysis_df.rename(columns={'emotions_connecting_10': 'connecting_happy'})
    # Rename column 'emotions_connecting_11' to 'connecting_guilty'
    clean_analysis_df = clean_analysis_df.rename(columns={'emotions_connecting_11': 'connecting_guilty'})
    # Rename column 'emotions_connecting_12' to 'connecting_numb'
    clean_analysis_df = clean_analysis_df.rename(columns={'emotions_connecting_12': 'connecting_numb'})
    # Rename column 'emotions_connecting_13' to 'connecting_stressed'
    clean_analysis_df = clean_analysis_df.rename(columns={'emotions_connecting_13': 'connecting_stressed'})
    return clean_analysis_df

clean_analysis_df = clean_data(clean_analysis_df.copy())
clean_analysis_df.head()
# Out:
#             start_date             end_date      status    ip_address  \
# 2  2024-01-24 16:52:41  2024-01-24 19:29:43  IP Address  155.98.131.0
# 3  2024-01-24 16:32:42  2024-01-24 19:27:07  IP Address  155.98.131.2
# 4  2024-01-24 16:36:52  2024-01-24 19:30:16  IP Address  155.98.131.4
# 5  2024-01-24 19:30:11  2024-01-26 15:17:30  IP Address  155.98.131.2
# 6  2024-01-24 19:30:17  2024-01-26 15:20:15  IP Address  155.98.131.4
#
#   progress duration_in_seconds finished        recorded_date  \
# 2      100                9422     True  2024-01-24 19:29:44
# 3      100               10464     True  2024-01-24 19:27:07
# 4      100               10404     True  2024-01-24 19:30:17
# 5      100              157638     True  2024-01-26 15:17:31
# 6      100              157797     True  2024-01-26 15:20:16
#
#          response_id recipient_last_name  ...        q49_48        q49_49  \
# 2  R_7JjAHZBazmS3x73                 NaN  ...  A little bit  A little bit
# ...
